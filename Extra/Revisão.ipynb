# %%
while True:
    pergunta = input("Qual o número do seu crush ?")
    if pergunta == "40028922":
        print("Migeul gatão, imaginei ")
        break
    else:
        print("Erradoo, burroo")
# Out:
# Migeul gatão, imaginei

# %%
while True:
    pergunta = int(input("Escolha um número ?"))
    if pergunta == 20:
        print("Ganhou 100zin")
        break
    else:
        print("Número errado, tente novamente")
# Out:
# Ganhou 100zin

# %%
numero_escolhido = int(input("Digite um número :"))
numero_anterior = numero_escolhido - 1
numero_sucessivo = numero_escolhido + 1
print(f"O número que você digitou foi {numero_escolhido}")
print(f"O número anterior ao que você escolheu é {numero_anterior}")
print(f"O número sucessivo ao que você escolheu é {numero_sucessivo}")
# Out:
# O número que você digitou foi 7
# O número anterior ao que você escolheu é 6
# O número sucessivo ao que você escolheu é 8

# %%
numero = int(input("Digite um número"))
for i in range(numero):
    print(f"Número: {i}")
# Out:
# Número: 0
# Número: 1
# Número: 2
# Número: 3
# Número: 4
# Número: 5
# Número: 6
# Número: 7
# Número: 8
# Número: 9

# %%
contatin = int(input("Quantos contatinhos você tem ?"))
for i in range(contatin):
    nome_contatin = input("Digite o nome do seus contatinhos")
    print(nome_contatin)

# %%
hobbies = int(input("Quantos hobbies você tem :"))
for i in range(hobbies):
    nome_hobbies = input("Digite o nome dos hobbies")
    print(nome_hobbies)
# Out:
# Jogar bola
# Jogar videogame
# dormir

# %%
quantidade = int(input("Quantas notas você tem ?"))
for i in range(quantidade):
    nota = int(input("Digite suas notas:"))
    if nota >  7.0:
        print("Boa!!!")
    else:
        print("Sou imune ao conhecimento")
# Out:
# Boa!!!

# %%
compras = int(input("Quantos produtos você deseja comprar"))
for compras in range(compras):
    nome_produto = input("Digite o nome do produto que você deseja comprar:")
    preco = float(input("Digite o valor do produto: "))
    if preco >= 50:
        print("Ta caro!!!")
    elif preco >= 40 and preco <= 45:
        print("Esta aceitavel")
    else:
        print("Ta barato demaisssss")
# Out:
# Ta barato demaisssss
# Esta aceitavel
